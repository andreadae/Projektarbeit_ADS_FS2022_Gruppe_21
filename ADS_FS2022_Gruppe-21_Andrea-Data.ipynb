# %% [markdown]
# # <font color='black'>Applied Data Science Project Grupp 21 - FS 2022 - Andrea</font>
# # <font color='blue'>Fahrzeug-Bilder-Erkennung</font>
# <font color="blue">Quellen</font>
# <li>flickr_api_example/flickr_example_01.ipynb von Mario Gellrich</li>
# <li>https://www.tensorflow.org/tutorials/images/classification</li>
# <li>Exercise6-transfer_learning.ipynb von Elena Gavarin</li>

# %% [markdown]
# ## <font color='blue'>Notebook Preparation</font>
# <font color='blue'>Installed Tools</font>
# <li>pip install pandas</li>
# <li>pip install numpy</li>
# <li>pip install matplotlib.pyplot</li>
# <li>pip install tensorflow</li>
# <li>pip install PIL</li>
# <li>pip install flickrapi</>

# %%
import os
from flickrapi import FlickrAPI


print ("Import Libraries Successfull")
# Out:
# Import Libraries Successfull

# %% [markdown]
# # Flickr REST API

# %%
# Working directory
os.chdir('/Users/andreazkb/Documents/ZHAW/ADS/Labs/week 2/flickr_api_example')
print(os.getcwd())

# Keys for flickr API
FLICKR_PUBLIC = 'c8cf6de83798c6aa3bf7ff1bc3efc67e'
FLICKR_SECRET = '36f711532617cf85'

# Settings (extras = different resolution of photos)
flickr = FlickrAPI(FLICKR_PUBLIC, FLICKR_SECRET, format='parsed-json')
extras = 'url_sq,url_t,url_s,url_q,url_m,url_n,url_z,url_c,url_l,url_o'

# Get information about photos
cont = flickr.photos.search(text='colored birds', per_page=5, extras=extras)
photos = cont['photos']

# Object type
print(type(photos))

# Print information about photos (note than no photos are printed)
from pprint import pprint
pprint(photos)
# Out:
# /Users/andreazkb/Documents/ZHAW/ADS/Labs/week 2/flickr_api_example
# <class 'dict'>
# {'page': 1,
#  'pages': 12667,
#  'perpage': 5,
#  'photo': [{'farm': 66,
#             'height_c': 600,
#             'height_l': 768,
#             'height_m': 375,
#             'height_n': 240,
#             'height_q': 150,
#             'height_s': 180,
#             'height_sq': 75,
#             'height_t': 75,
#             'height_z': 480,
#             'id': '52121164683',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '71833159@N00',
#             'secret': '6318743136',
#             'server': '65535',
#             'title': '02 Bobolink / Dolichonyx oryzivorus, male',
#             'url_c': 'https://live.staticflickr.com/65535/52121164683_6318743136_c.jpg',
#             'url_l': 'https://live.staticflickr.com/65535/52121164683_6318743136_b.jpg',
#             'url_m': 'https://live.staticflickr.com/65535/52121164683_6318743136.jpg',
#             'url_n': 'https://live.staticflickr.com/65535/52121164683_6318743136_n.jpg',
#             'url_q': 'https://live.staticflickr.com/65535/52121164683_6318743136_q.jpg',
#             'url_s': 'https://live.staticflickr.com/65535/52121164683_6318743136_m.jpg',
#             'url_sq': 'https://live.staticflickr.com/65535/52121164683_6318743136_s.jpg',
#             'url_t': 'https://live.staticflickr.com/65535/52121164683_6318743136_t.jpg',
#             'url_z': 'https://live.staticflickr.com/65535/52121164683_6318743136_z.jpg',
#             'width_c': 800,
#             'width_l': 1024,
#             'width_m': 500,
#             'width_n': 320,
#             'width_q': 150,
#             'width_s': 240,
#             'width_sq': 75,
#             'width_t': 100,
#             'width_z': 640},
#            {'farm': 66,
#             'height_c': 572,
#             'height_l': 732,
#             'height_m': 357,
#             'height_n': 229,
#             'height_q': 150,
#             'height_s': 171,
#             'height_sq': 75,
#             'height_t': 71,
#             'height_z': 457,
#             'id': '52117269527',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '102539285@N04',
#             'secret': '0ef12c09b7',
#             'server': '65535',
#             'title': 'Clay-colored Sparrow',
#             'url_c': 'https://live.staticflickr.com/65535/52117269527_0ef12c09b7_c.jpg',
#             'url_l': 'https://live.staticflickr.com/65535/52117269527_0ef12c09b7_b.jpg',
#             'url_m': 'https://live.staticflickr.com/65535/52117269527_0ef12c09b7.jpg',
#             'url_n': 'https://live.staticflickr.com/65535/52117269527_0ef12c09b7_n.jpg',
#             'url_q': 'https://live.staticflickr.com/65535/52117269527_0ef12c09b7_q.jpg',
#             'url_s': 'https://live.staticflickr.com/65535/52117269527_0ef12c09b7_m.jpg',
#             'url_sq': 'https://live.staticflickr.com/65535/52117269527_0ef12c09b7_s.jpg',
#             'url_t': 'https://live.staticflickr.com/65535/52117269527_0ef12c09b7_t.jpg',
#             'url_z': 'https://live.staticflickr.com/65535/52117269527_0ef12c09b7_z.jpg',
#             'width_c': 800,
#             'width_l': 1024,
#             'width_m': 500,
#             'width_n': 320,
#             'width_q': 150,
#             'width_s': 240,
#             'width_sq': 75,
#             'width_t': 100,
#             'width_z': 640},
#            {'farm': 66,
#             'height_c': 533,
#             'height_l': 683,
#             'height_m': 333,
#             'height_n': 213,
#             'height_o': 2401,
#             'height_q': 150,
#             'height_s': 160,
#             'height_sq': 75,
#             'height_t': 67,
#             'height_z': 427,
#             'id': '52116431774',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '59831440@N04',
#             'secret': 'c68b7445a7',
#             'server': '65535',
#             'title': 'Clay-colored Sparrow (FOY 2022)',
#             'url_c': 'https://live.staticflickr.com/65535/52116431774_c68b7445a7_c.jpg',
#             'url_l': 'https://live.staticflickr.com/65535/52116431774_c68b7445a7_b.jpg',
#             'url_m': 'https://live.staticflickr.com/65535/52116431774_c68b7445a7.jpg',
#             'url_n': 'https://live.staticflickr.com/65535/52116431774_c68b7445a7_n.jpg',
#             'url_o': 'https://live.staticflickr.com/65535/52116431774_3baa0d8c5f_o.jpg',
#             'url_q': 'https://live.staticflickr.com/65535/52116431774_c68b7445a7_q.jpg',
#             'url_s': 'https://live.staticflickr.com/65535/52116431774_c68b7445a7_m.jpg',
#             'url_sq': 'https://live.staticflickr.com/65535/52116431774_c68b7445a7_s.jpg',
#             'url_t': 'https://live.staticflickr.com/65535/52116431774_c68b7445a7_t.jpg',
#             'url_z': 'https://live.staticflickr.com/65535/52116431774_c68b7445a7_z.jpg',
#             'width_c': 800,
#             'width_l': 1024,
#             'width_m': 500,
#             'width_n': 320,
#             'width_o': 3602,
#             'width_q': 150,
#             'width_s': 240,
#             'width_sq': 75,
#             'width_t': 100,
#             'width_z': 640},
#            {'farm': 66,
#             'height_c': 569,
#             'height_l': 715,
#             'height_m': 355,
#             'height_n': 227,
#             'height_o': 715,
#             'height_q': 150,
#             'height_s': 171,
#             'height_sq': 75,
#             'height_t': 71,
#             'height_z': 455,
#             'id': '52116262704',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '54249623@N08',
#             'secret': '8b1a46d085',
#             'server': '65535',
#             'title': 'Flame-colored Tanager (Piranga bidentata)',
#             'url_c': 'https://live.staticflickr.com/65535/52116262704_8b1a46d085_c.jpg',
#             'url_l': 'https://live.staticflickr.com/65535/52116262704_8b1a46d085_b.jpg',
#             'url_m': 'https://live.staticflickr.com/65535/52116262704_8b1a46d085.jpg',
#             'url_n': 'https://live.staticflickr.com/65535/52116262704_8b1a46d085_n.jpg',
#             'url_o': 'https://live.staticflickr.com/65535/52116262704_668b31a520_o.jpg',
#             'url_q': 'https://live.staticflickr.com/65535/52116262704_8b1a46d085_q.jpg',
#             'url_s': 'https://live.staticflickr.com/65535/52116262704_8b1a46d085_m.jpg',
#             'url_sq': 'https://live.staticflickr.com/65535/52116262704_8b1a46d085_s.jpg',
#             'url_t': 'https://live.staticflickr.com/65535/52116262704_8b1a46d085_t.jpg',
#             'url_z': 'https://live.staticflickr.com/65535/52116262704_8b1a46d085_z.jpg',
#             'width_c': 800,
#             'width_l': 1006,
#             'width_m': 500,
#             'width_n': 320,
#             'width_o': 1006,
#             'width_q': 150,
#             'width_s': 240,
#             'width_sq': 75,
#             'width_t': 100,
#             'width_z': 640},
#            {'farm': 66,
#             'height_c': 510,
#             'height_l': 653,
#             'height_m': 319,
#             'height_n': 204,
#             'height_o': 765,
#             'height_q': 150,
#             'height_s': 153,
#             'height_sq': 75,
#             'height_t': 64,
#             'height_z': 408,
#             'id': '52114844607',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '192209578@N05',
#             'secret': '2ae006b94e',
#             'server': '65535',
#             'title': 'Rufous-backed dwarf kingfisher',
#             'url_c': 'https://live.staticflickr.com/65535/52114844607_2ae006b94e_c.jpg',
#             'url_l': 'https://live.staticflickr.com/65535/52114844607_2ae006b94e_b.jpg',
#             'url_m': 'https://live.staticflickr.com/65535/52114844607_2ae006b94e.jpg',
#             'url_n': 'https://live.staticflickr.com/65535/52114844607_2ae006b94e_n.jpg',
#             'url_o': 'https://live.staticflickr.com/65535/52114844607_be4698a593_o.jpg',
#             'url_q': 'https://live.staticflickr.com/65535/52114844607_2ae006b94e_q.jpg',
#             'url_s': 'https://live.staticflickr.com/65535/52114844607_2ae006b94e_m.jpg',
#             'url_sq': 'https://live.staticflickr.com/65535/52114844607_2ae006b94e_s.jpg',
#             'url_t': 'https://live.staticflickr.com/65535/52114844607_2ae006b94e_t.jpg',
#             'url_z': 'https://live.staticflickr.com/65535/52114844607_2ae006b94e_z.jpg',
#             'width_c': 800,
#             'width_l': 1024,
#             'width_m': 500,
#             'width_n': 320,
#             'width_o': 1200,
#             'width_q': 150,
#             'width_s': 240,
#             'width_sq': 75,
#             'width_t': 100,
#             'width_z': 640}],
#  'total': 63333}
