# %% [markdown]
# # <font color='darkblue'>Applied Data Science Project Grupp 21 - FS 2022</font>
# # <font color='blue'>Teil 2: Classification Modell zur Fahrzeug-Bilder-Erkennung</font>
# <font color="blue">Quellen</font>
# <li>flickr_api_example/flickr_example_01.ipynb von Mario Gellrich</li>
# <li>https://www.tensorflow.org/tutorials/images/classification</li>
# <li>Exercise6-transfer_learning.ipynb von Elena Gavarin</li>
# <li>https://keras.io/guides/transfer_learning/</li>

# %% [markdown]
# ## <font color='blue'>Notebook Preparation</font>
# ### <font color='blue'>Libraries to install</font>
# <li>pip install pandas</li>
# <li>pip install numpy</li>
# <li>pip install matplotlib.pyplot</li>
# <li>pip install tensorflow</li>
# <li>pip install PIL</li>
# <li>pip install flickrapi</li>

# %% [markdown]
# ### <font color='blue'>Libraries to import</font>

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
import pandas as pd
import pathlib
import time

import PIL
from IPython.display import Image, display
import matplotlib.cm as cm

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

print ("Import Libraries Successfull")
# Out:
# Import Libraries Successfull

# %% [markdown]
# ### <font color='blue'>Set working directory</font>

# %%
#fill in your working directory
path="/Users/andreazkb/Documents/ZHAW/ADS/Projekt/"
os.chdir(path)
os.getcwd()
# Out:
# '/Users/andreazkb/Documents/ZHAW/ADS/Projekt'

# %% [markdown]
# ## <font color='blue'>Load and prepare data</font>
# <font color='blue'>Load the collected images and split into train and validation set. The images are organized in two folders, at the same time those folders give the images their class. </font>

# %%
data_dir = os.path.join(os.curdir, 'gruppe21-data/')
BATCH_SIZE = 32
IMG_SIZE = (192, 192)

train_dataset = tf.keras.utils.image_dataset_from_directory(data_dir,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE,
                                                            shuffle=True,
                                                            seed=999,
                                                            validation_split=0.20,
                                                            subset = "training")

validation_dataset = tf.keras.utils.image_dataset_from_directory(data_dir,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE,
                                                            shuffle=True,
                                                            seed=999,
                                                            validation_split=0.20,
                                                            subset = "validation")
# Out:
# Found 12 files belonging to 2 classes.
# Using 10 files for training.
# Found 12 files belonging to 2 classes.
# Using 2 files for validation.

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
val_batches = tf.data.experimental.cardinality(validation_dataset)
test_dataset = validation_dataset.take(val_batches // 5)
val_dataset = validation_dataset.skip(val_batches // 5)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 1
# Number of test batches: 0

# %% [markdown]
# <font color='blue'>Improvement of performance of model training. The Autotune function checks the load on runtime and optimizes the distribution of CPU. </font>

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# <font color='blue'>Insert data augmentation to increase diversity on input and reduce overfitting </font>

# %%
with tf.device('/cpu:0'):
    data_augmentation = tf.keras.Sequential([
        tf.keras.layers.experimental.preprocessing.RandomFlip()
    ])

# %%
with tf.device('/cpu:0'):
    for image, _ in train_dataset.take(1):
      plt.figure(figsize=(10, 10))
      first_image = image[0]
      for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')

# %% [markdown]
# ## <font color='blue'>Classification model</font>
# <font color='blue'>The use of an existing and pretrained model reduces complexity for classification tasks as well as helps building fast and performant models. </font>
# ### <font color="blue">Transfer model MobileNetV2</font>
# <font color="blue">For this case the MobileNetV2 model is used, since it is specifically trained on image classification. The model is created based on the MobileNet V2, the layers are freezed then to avoid destroying information they contain.</font>

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# %%
# Create the base model from the pre-trained model MobileNet V2

IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (10, 6, 6, 1280)

# %%
base_model.trainable = False

# %%
base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_192"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 192, 192, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 96, 96, 32)   864         ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 96, 96, 32)   128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 96, 96, 32)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 96, 96, 32)  288         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 96, 96, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 96, 96, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
# ...

# %% [markdown]
# <font color="blue">According to the inpput from class (Exercise6-transfer_learning) the following steps are taken with the base model:
#
# <li>Combining the base model with fully connected layers (tf.keras.layers.Dense)</li>
# <li>Insert data augmentation as input</li>
# <li>Insert preprossessing function</li>
# <li>Insert the base model</li>
# <li>Add classification head</li>
# <li>convert these features into a single prediction per image</li>
# </font>

# %%
inputs = tf.keras.Input(shape=IMG_SHAPE)
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = tf.keras.layers.Dense(1, activation="sigmoid")(x) 
model = tf.keras.Model(inputs, outputs)

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 192, 192, 3)]     0
#
#  sequential (Sequential)     (None, 192, 192, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 192, 192, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 192, 192, 3)      0
#  a)
#
#  mobilenetv2_1.00_192 (Funct  (None, 6, 6, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 1)                 1281
#
# ...
# Total params: 2,259,265
# Trainable params: 1,281
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# ### <font color="blue">Train the Model</font>

# %%
initial_epochs = 20

loss0, accuracy0 = model.evaluate(validation_dataset)
# Out:
# 1/1 [==============================] - 0s 65ms/step - loss: 0.7045 - accuracy: 0.5000

# %%
print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(accuracy0))
# Out:
# initial loss: 0.70
# initial accuracy: 0.50

# %%
history = model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset)
# Out:
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7ff55ea66440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7ff55ea66440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
loss, accuracy = model.evaluate(test_dataset)
print('Test accuracy :', accuracy)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /var/folders/bs/1klrhz517b58dp6rpn8hk1b40000gn/T/ipykernel_1029/104695744.py in <module>
# ----> 1 loss, accuracy = model.evaluate(test_dataset)
#       2 print('Test accuracy :', accuracy)
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/keras/utils/generic_utils.py in update(self, current, values, finalize)
#     921
#     922       if self.target is not None:
# --> 923         numdigits = int(np.log10(self.target)) + 1
# ...

# %% [markdown]
# ### <font color="blue">Evaluating the Model & Prediction</font>
# <font color="blue">With a batch of images we test the model and the predictions</font>

# %%
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch).flatten()

predictions = tf.where(predictions < 0.5, 0, 1)

print('Predictions:\n', predictions.numpy())
print('Labels:\n', label_batch)

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(image_batch[i].astype("uint8"))
  plt.title(class_names[predictions[i]])
  plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# OutOfRangeError                           Traceback (most recent call last)
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in __next__(self)
#     835     try:
# --> 836       return self._next_internal()
#     837     except errors.OutOfRangeError:
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in _next_internal(self)
#     821           output_types=self._flat_output_types,
# --> 822           output_shapes=self._flat_output_shapes)
#     823
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/ops/gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    2922     except _core._NotOkStatusException as e:
# -> 2923       _ops.raise_from_not_ok_status(e, name)
#    2924     except _core._FallbackException:
#
# ...
