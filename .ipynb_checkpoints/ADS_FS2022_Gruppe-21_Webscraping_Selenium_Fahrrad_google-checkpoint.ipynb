# %% [markdown]
# # <font color='black'>Applied Data Science Project Grupp 21 - FS 2022</font>
# # <font color='blue'>Web Scraping Google Images Selenium - Fahrrad</font>
# <font color="blue">Quellen</font>
# <li>web_scraping_python_selenium.ipynb von Mario Gellrich</li>
# <li>https://selenium-python.readthedocs.io/installation.html</li>
# <li>https://www.youtube.com/watch?v=Yt6Gay8nuy0</li>

# %% [markdown]
# ## <font color='blue'>Notebook Preparation</font>
# <font color='blue'>Installed Libraries</font>
# <li>import bs4</li>
# <li>from selenium import webdriver</li>
# <li>from selenium.webdriver.common.by import By</li>
# <li>import requests</li>
# <li>import time</li>
# <li>import os</li>

# %%
#Imported libraries
import bs4
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
import os
import time

# %%
#Creating a directory to save images
folder_name = 'Fahrrad'
if not os.path.isdir(folder_name):
    os.makedirs(folder_name)

def download_image(url, folder_name, num):

    # write image to file
    reponse = requests.get(url)
    if reponse.status_code==200:
        with open(os.path.join(folder_name, str(num)+".jpg"), 'wb') as file:
            file.write(reponse.content)

#Start Chrome driver
PATH ="C:\\Users\\uemio\\Documents\\GitHub\\Projektarbeit_ADS_FS2022_Gruppe_21\\chromedriver.exe"
driver = webdriver.Chrome(PATH)

# Website to scrape
search_URL = "https://www.google.com/search?q=fahrrad&tbm=isch"
driver.get(search_URL)

a = input("Waiting...")

#Scrolling all the way up
driver.execute_script("window.scrollTo(0, 0);")

page_html = driver.page_source
pageSoup = bs4.BeautifulSoup(page_html, 'html.parser')
containers = pageSoup.findAll('div', {'class':"bRMDJf islir"} )

len_containers = len(containers)
print("Found %s images containers"%(len_containers))

for i in range(1,len_containers+1):
    if i %25 ==0:
        continue
        
    xPath="""//*[@id="islrg"]/div[1]/div[%s]/a[1]/div[1]"""%(i)
    
    #Grabbing the URL of the small preview image
    previewImageXPath = """//*[@id="islrg"]/div[1]/div[%s]/a[1]/div[1]/img"""%(i)
    previewImageElement = driver.find_element(by=By.XPATH, value=previewImageXPath)
    previewImageURL = previewImageElement.get_attribute("src")
       
    #Clicking on the image container
    driver.find_element(by=By.XPATH, value=xPath).click()
    
    #Starting a while True loop to wait until we the URL inside the large image view is different from the preview one
    timeStarted = time.time()
    while True:
        
        imageElement = driver.find_element(by=By.XPATH, value="""//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img""")
        imageURL = imageElement.get_attribute('src')

        print("Waiting for the full res image")         
        if imageURL!= previewImageURL:
            #print("Aktual URL",imageURL)
            print("Full res URL:", imageURL)
            break
   
        else:
            #making a timeout if the full res image can't be loaded
            currentTime = time.time()
            
            if currentTime - timeStarted >20:
                print("Timeout, downloading a lower resolution image and move onto")
                break
                
    #Downloading image
    try:
        download_image(imageURL,folder_name, i)
        print("Downloaded element %s out of %s total. URL: %s" %(i,len_containers+1, imageURL))
    except:
        print("Couldn't download an image %s, continuing downloading the next one" %(i))

#Close driver
driver.quit()
# Out:
# <ipython-input-4-b5646bf29915>:16: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH)
# Waiting...
# Found 800 images containers
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Full res URL: https://upload.wikimedia.org/wikipedia/commons/thumb/d/db/15-07-12-Ciclistas-en-Mexico-RalfR-N3S_8973.jpg/800px-15-07-12-Ciclistas-en-Mexico-RalfR-N3S_8973.jpg
# Downloaded element 1 out of 801 total. URL: https://upload.wikimedia.org/wikipedia/commons/thumb/d/db/15-07-12-Ciclistas-en-Mexico-RalfR-N3S_8973.jpg/800px-15-07-12-Ciclistas-en-Mexico-RalfR-N3S_8973.jpg
# Waiting for the full res image
# Waiting for the full res image
# Full res URL: https://upload.wikimedia.org/wikipedia/commons/thumb/1/19/Bicycle_diagram-de.svg/600px-Bicycle_diagram-de.svg.png
# Downloaded element 2 out of 801 total. URL: https://upload.wikimedia.org/wikipedia/commons/thumb/1/19/Bicycle_diagram-de.svg/600px-Bicycle_diagram-de.svg.png
# Waiting for the full res image
# Full res URL: https://kristallvelo.ch/wp-content/uploads/UrbanRace-T-tuerkis.jpg
# Downloaded element 3 out of 801 total. URL: https://kristallvelo.ch/wp-content/uploads/UrbanRace-T-tuerkis.jpg
# Waiting for the full res image
# Full res URL: https://img.welt.de/img/wirtschaft/webwelt/mobile207692361/4172500277-ci102l-w1024/Bedarf-und-Budget-Der-Weg-zum-neuen-Fahrrad.jpg
# Downloaded element 4 out of 801 total. URL: https://img.welt.de/img/wirtschaft/webwelt/mobile207692361/4172500277-ci102l-w1024/Bedarf-und-Budget-Der-Weg-zum-neuen-Fahrrad.jpg
# Waiting for the full res image
# Full res URL: https://cdn.fahrrad-xxl.de/media/thumbs/642309_7133255.jpg
# Downloaded element 5 out of 801 total. URL: https://cdn.fahrrad-xxl.de/media/thumbs/642309_7133255.jpg
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Waiting for the full res image
# Timeout, downloading a lower resolution image and move onto
# Couldn't download an image 6, continuing downloading the next one
# Waiting for the full res image
# Waiting for the full res image
# Full res URL: https://img.freepik.com/vektoren-kostenlos/fahrradaufkleber-logo-symbol-vektor-radfahren-fahrrad-zeichen-vektor-auf-isoliertem-hintergrund-eps-10_399089-2169.jpg?w=2000
# Downloaded element 7 out of 801 total. URL: https://img.freepik.com/vektoren-kostenlos/fahrradaufkleber-logo-symbol-vektor-radfahren-fahrrad-zeichen-vektor-auf-isoliertem-hintergrund-eps-10_399089-2169.jpg?w=2000
# Waiting for the full res image
# Full res URL: https://media.istockphoto.com/vectors/bike-in-trendy-colors-on-white-background-vector-flat-illustration-vector-id1205503578?k=20&m=1205503578&s=612x612&w=0&h=ulaV4TFJYvV902GBsIxPbWiTiIIArbqDxnBKmxEGW7A=
# Downloaded element 8 out of 801 total. URL: https://media.istockphoto.com/vectors/bike-in-trendy-colors-on-white-background-vector-flat-illustration-vector-id1205503578?k=20&m=1205503578&s=612x612&w=0&h=ulaV4TFJYvV902GBsIxPbWiTiIIArbqDxnBKmxEGW7A=
# Waiting for the full res image
# Full res URL: https://may-ltd.com/wp-content/uploads/2020/03/IMG_5722_shadow.jpg
# Downloaded element 9 out of 801 total. URL: https://may-ltd.com/wp-content/uploads/2020/03/IMG_5722_shadow.jpg
# Waiting for the full res image
# Waiting for the full res image
# Full res URL: https://cdn.mdr.de/ratgeber/fahrrad-reisen-104_v-variantBig16x9_w-1280_zc-b903ef86.jpg?version=26444
# Downloaded element 10 out of 801 total. URL: https://cdn.mdr.de/ratgeber/fahrrad-reisen-104_v-variantBig16x9_w-1280_zc-b903ef86.jpg?version=26444
# Waiting for the full res image
# Full res URL: https://medias.maisonsdumonde.com/image/upload/q_auto,f_auto/w_500/img/wanddeko-fahrrad-aus-schwarzem-metall-186x108-1000-3-1-164903_1.jpg
# Downloaded element 11 out of 801 total. URL: https://medias.maisonsdumonde.com/image/upload/q_auto,f_auto/w_500/img/wanddeko-fahrrad-aus-schwarzem-metall-186x108-1000-3-1-164903_1.jpg
# Waiting for the full res image
# Full res URL: https://images.pexels.com/photos/100582/pexels-photo-100582.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500
# Downloaded element 12 out of 801 total. URL: https://images.pexels.com/photos/100582/pexels-photo-100582.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500
# Waiting for the full res image
# Full res URL: https://img.freepik.com/vektoren-kostenlos/illustration-von-fahrrad_53876-44045.jpg?w=2000
# Downloaded element 13 out of 801 total. URL: https://img.freepik.com/vektoren-kostenlos/illustration-von-fahrrad_53876-44045.jpg?w=2000
# Waiting for the full res image
# Waiting for the full res image
# Full res URL: https://www.test.de/file/image/b7/21/b5bd608e-8139-418b-8d49-2ee71f223137-web/5788284_fahrrad-technik-special_202102_01.jpg
# Downloaded element 14 out of 801 total. URL: https://www.test.de/file/image/b7/21/b5bd608e-8139-418b-8d49-2ee71f223137-web/5788284_fahrrad-technik-special_202102_01.jpg
# Waiting for the full res image
# Full res URL: https://www.diamantrad.com/wp-content/uploads/2021/01/fahrrad-mittel-zur-emanzipation-titelbild-diamantrad-blog.jpg
# Downloaded element 15 out of 801 total. URL: https://www.diamantrad.com/wp-content/uploads/2021/01/fahrrad-mittel-zur-emanzipation-titelbild-diamantrad-blog.jpg
# Waiting for the full res image
# Full res URL: https://media.gq-magazin.de/photos/6061dfb10851a6fd7b5e6b16/16:9/w_1280,c_limit/reevo.jpg
# Downloaded element 16 out of 801 total. URL: https://media.gq-magazin.de/photos/6061dfb10851a6fd7b5e6b16/16:9/w_1280,c_limit/reevo.jpg
# Waiting for the full res image
# Full res URL: https://cdn.fahrrad-xxl.de/media/thumbs/642304_7133246.jpg
# Downloaded element 17 out of 801 total. URL: https://cdn.fahrrad-xxl.de/media/thumbs/642304_7133246.jpg
# Waiting for the full res image
# Full res URL: https://www.snoozeproject.de/files/uploads/2021/09/Traumdeuter_Illu_Fahrrad.jpg
# Downloaded element 18 out of 801 total. URL: https://www.snoozeproject.de/files/uploads/2021/09/Traumdeuter_Illu_Fahrrad.jpg
# Waiting for the full res image
# Full res URL: https://www.fahrradmagazin.net/bilder/2013/12/fahrradfahren-winter.jpg
# Downloaded element 19 out of 801 total. URL: https://www.fahrradmagazin.net/bilder/2013/12/fahrradfahren-winter.jpg
# Waiting for the full res image
# Full res URL: https://contents.mediadecathlon.com/p2268842/k$cb7e4cb47023dbb767aad4df7902afef/sq/8605830.jpg?format=auto&f=800x0&quality=40
# Downloaded element 20 out of 801 total. URL: https://contents.mediadecathlon.com/p2268842/k$cb7e4cb47023dbb767aad4df7902afef/sq/8605830.jpg?format=auto&f=800x0&quality=40
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-4-b5646bf29915> in <module>
#      42     #Grabbing the URL of the small preview image
#      43     previewImageXPath = """//*[@id="islrg"]/div[1]/div[%s]/a[1]/div[1]/img"""%(i)
# ---> 44     previewImageElement = driver.find_element(by=By.XPATH, value=previewImageXPath)
#      45     previewImageURL = previewImageElement.get_attribute("src")
#      46
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1246             value = '[name="%s"]' % value
#    1247
# -> 1248         return self.execute(Command.FIND_ELEMENT, {
#    1249             'using': by,
#    1250             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="islrg"]/div[1]/div[21]/a[1]/div[1]/img"}
#   (Session info: chrome=102.0.5005.63)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x006DD953+2414931]
# 	Ordinal0 [0x0066F5E1+1963489]
# 	Ordinal0 [0x0055C6B8+837304]
# 	Ordinal0 [0x00589500+1021184]
# 	Ordinal0 [0x0058979B+1021851]
# 	Ordinal0 [0x005B6502+1205506]
# 	Ordinal0 [0x005A44E4+1131748]
# 	Ordinal0 [0x005B4812+1198098]
# 	Ordinal0 [0x005A42B6+1131190]
# 	Ordinal0 [0x0057E860+976992]
# 	Ordinal0 [0x0057F756+980822]
# 	GetHandleVerifier [0x0094CC62+2510274]
# 	GetHandleVerifier [0x0093F760+2455744]
# 	GetHandleVerifier [0x0076EABA+551962]
# 	GetHandleVerifier [0x0076D916+547446]
# 	Ordinal0 [0x00675F3B+1990459]
# 	Ordinal0 [0x0067A898+2009240]
# 	Ordinal0 [0x0067A985+2009477]
# 	Ordinal0 [0x00683AD1+2046673]
# 	BaseThreadInitThunk [0x76FAFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77547A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77547A4E+238]
